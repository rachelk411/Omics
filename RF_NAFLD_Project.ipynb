# %% [markdown]
# ### Overview:
# - **Goal**: The project aims to classify stages of Non-Alcoholic Fatty Liver Disease (NAFLD) using gene expression data from the GSE49541 GEO dataset. The stages being classified are either "mild" or "advanced."
#
# - **Data**:
#   - **X (Features)**: Gene expression values.
#   - **Y (Target)**: NAFLD stages (mild or advanced).
#
# - **Model**: A Random Forest classifier is used to predict the stage of NAFLD.
#
# ### Performance Metrics:
# - **Accuracy**: 94%
# - **Precision**: 94%
# - **Recall**: 93%
# - **F1 Score**: 93%

# %%
# !pip install GEOparse
# Out:
# Requirement already satisfied: GEOparse in /usr/local/lib/python3.10/dist-packages (2.0.4)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.10/dist-packages (from GEOparse) (1.26.4)
# Requirement already satisfied: pandas>=0.17 in /usr/local/lib/python3.10/dist-packages (from GEOparse) (2.1.4)
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from GEOparse) (2.32.3)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from GEOparse) (4.66.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.17->GEOparse) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.17->GEOparse) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.17->GEOparse) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->GEOparse) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->GEOparse) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->GEOparse) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->GEOparse) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.17->GEOparse) (1.16.0)

# %%
import GEOparse

# %%
#Load the soft file
from google.colab import drive
drive.mount('/content/drive')

soft_file = GEOparse.get_GEO(filepath="/content/drive/MyDrive/GSE49541_family.soft")
# Out:
# 03-Sep-2024 05:53:50 INFO GEOparse - Parsing /content/drive/MyDrive/GSE49541_family.soft:
# INFO:GEOparse:Parsing /content/drive/MyDrive/GSE49541_family.soft:
# 03-Sep-2024 05:53:50 DEBUG GEOparse - DATABASE: GeoMiame
# DEBUG:GEOparse:DATABASE: GeoMiame
# 03-Sep-2024 05:53:50 DEBUG GEOparse - SERIES: GSE49541
# DEBUG:GEOparse:SERIES: GSE49541
# 03-Sep-2024 05:53:50 DEBUG GEOparse - PLATFORM: GPL570
# DEBUG:GEOparse:PLATFORM: GPL570
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /usr/local/lib/python3.10/dist-packages/GEOparse/GEOparse.py:401: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   return read_csv(StringIO(data), index_col=None, sep="\t")
# 03-Sep-2024 05:53:58 DEBUG GEOparse - SAMPLE: GSM789110
# DEBUG:GEOparse:SAMPLE: GSM789110
# 03-Sep-2024 05:53:59 DEBUG GEOparse - SAMPLE: GSM789111
# DEBUG:GEOparse:SAMPLE: GSM789111
# 03-Sep-2024 05:53:59 DEBUG GEOparse - SAMPLE: GSM789112
# DEBUG:GEOparse:SAMPLE: GSM789112
# 03-Sep-2024 05:53:59 DEBUG GEOparse - SAMPLE: GSM789113
# DEBUG:GEOparse:SAMPLE: GSM789113
# 03-Sep-2024 05:54:00 DEBUG GEOparse - SAMPLE: GSM789114
# DEBUG:GEOparse:SAMPLE: GSM789114
# 03-Sep-2024 05:54:00 DEBUG GEOparse - SAMPLE: GSM789115
# DEBUG:GEOparse:SAMPLE: GSM789115
# 03-Sep-2024 05:54:00 DEBUG GEOparse - SAMPLE: GSM789116
# DEBUG:GEOparse:SAMPLE: GSM789116
# 03-Sep-2024 05:54:00 DEBUG GEOparse - SAMPLE: GSM789117
# DEBUG:GEOparse:SAMPLE: GSM789117
# 03-Sep-2024 05:54:01 DEBUG GEOparse - SAMPLE: GSM789118
# DEBUG:GEOparse:SAMPLE: GSM789118
# 03-Sep-2024 05:54:01 DEBUG GEOparse - SAMPLE: GSM789119
# DEBUG:GEOparse:SAMPLE: GSM789119
# 03-Sep-2024 05:54:01 DEBUG GEOparse - SAMPLE: GSM789120
# DEBUG:GEOparse:SAMPLE: GSM789120
# 03-Sep-2024 05:54:01 DEBUG GEOparse - SAMPLE: GSM789121
# DEBUG:GEOparse:SAMPLE: GSM789121
# 03-Sep-2024 05:54:02 DEBUG GEOparse - SAMPLE: GSM789122
# DEBUG:GEOparse:SAMPLE: GSM789122
# 03-Sep-2024 05:54:02 DEBUG GEOparse - SAMPLE: GSM789123
# DEBUG:GEOparse:SAMPLE: GSM789123
# 03-Sep-2024 05:54:02 DEBUG GEOparse - SAMPLE: GSM789124
# DEBUG:GEOparse:SAMPLE: GSM789124
# 03-Sep-2024 05:54:03 DEBUG GEOparse - SAMPLE: GSM789125
# DEBUG:GEOparse:SAMPLE: GSM789125
# 03-Sep-2024 05:54:03 DEBUG GEOparse - SAMPLE: GSM789126
# DEBUG:GEOparse:SAMPLE: GSM789126
# 03-Sep-2024 05:54:03 DEBUG GEOparse - SAMPLE: GSM789127
# DEBUG:GEOparse:SAMPLE: GSM789127
# 03-Sep-2024 05:54:03 DEBUG GEOparse - SAMPLE: GSM789128
# DEBUG:GEOparse:SAMPLE: GSM789128
# 03-Sep-2024 05:54:04 DEBUG GEOparse - SAMPLE: GSM789129
# DEBUG:GEOparse:SAMPLE: GSM789129
# 03-Sep-2024 05:54:04 DEBUG GEOparse - SAMPLE: GSM789130
# DEBUG:GEOparse:SAMPLE: GSM789130
# 03-Sep-2024 05:54:04 DEBUG GEOparse - SAMPLE: GSM789131
# DEBUG:GEOparse:SAMPLE: GSM789131
# 03-Sep-2024 05:54:05 DEBUG GEOparse - SAMPLE: GSM789132
# DEBUG:GEOparse:SAMPLE: GSM789132
# 03-Sep-2024 05:54:05 DEBUG GEOparse - SAMPLE: GSM789133
# DEBUG:GEOparse:SAMPLE: GSM789133
# 03-Sep-2024 05:54:05 DEBUG GEOparse - SAMPLE: GSM789134
# DEBUG:GEOparse:SAMPLE: GSM789134
# 03-Sep-2024 05:54:06 DEBUG GEOparse - SAMPLE: GSM789135
# DEBUG:GEOparse:SAMPLE: GSM789135
# 03-Sep-2024 05:54:06 DEBUG GEOparse - SAMPLE: GSM789136
# DEBUG:GEOparse:SAMPLE: GSM789136
# 03-Sep-2024 05:54:06 DEBUG GEOparse - SAMPLE: GSM789137
# DEBUG:GEOparse:SAMPLE: GSM789137
# 03-Sep-2024 05:54:06 DEBUG GEOparse - SAMPLE: GSM789138
# DEBUG:GEOparse:SAMPLE: GSM789138
# 03-Sep-2024 05:54:07 DEBUG GEOparse - SAMPLE: GSM789139
# DEBUG:GEOparse:SAMPLE: GSM789139
# 03-Sep-2024 05:54:07 DEBUG GEOparse - SAMPLE: GSM789140
# DEBUG:GEOparse:SAMPLE: GSM789140
# 03-Sep-2024 05:54:07 DEBUG GEOparse - SAMPLE: GSM789141
# DEBUG:GEOparse:SAMPLE: GSM789141
# 03-Sep-2024 05:54:08 DEBUG GEOparse - SAMPLE: GSM789142
# DEBUG:GEOparse:SAMPLE: GSM789142
# 03-Sep-2024 05:54:08 DEBUG GEOparse - SAMPLE: GSM789143
# DEBUG:GEOparse:SAMPLE: GSM789143
# 03-Sep-2024 05:54:08 DEBUG GEOparse - SAMPLE: GSM789144
# DEBUG:GEOparse:SAMPLE: GSM789144
# 03-Sep-2024 05:54:08 DEBUG GEOparse - SAMPLE: GSM789145
# DEBUG:GEOparse:SAMPLE: GSM789145
# 03-Sep-2024 05:54:09 DEBUG GEOparse - SAMPLE: GSM789146
# DEBUG:GEOparse:SAMPLE: GSM789146
# 03-Sep-2024 05:54:09 DEBUG GEOparse - SAMPLE: GSM789147
# DEBUG:GEOparse:SAMPLE: GSM789147
# 03-Sep-2024 05:54:09 DEBUG GEOparse - SAMPLE: GSM789148
# DEBUG:GEOparse:SAMPLE: GSM789148
# 03-Sep-2024 05:54:09 DEBUG GEOparse - SAMPLE: GSM789149
# DEBUG:GEOparse:SAMPLE: GSM789149
# 03-Sep-2024 05:54:10 DEBUG GEOparse - SAMPLE: GSM789150
# DEBUG:GEOparse:SAMPLE: GSM789150
# 03-Sep-2024 05:54:10 DEBUG GEOparse - SAMPLE: GSM789151
# DEBUG:GEOparse:SAMPLE: GSM789151
# 03-Sep-2024 05:54:10 DEBUG GEOparse - SAMPLE: GSM789152
# DEBUG:GEOparse:SAMPLE: GSM789152
# 03-Sep-2024 05:54:11 DEBUG GEOparse - SAMPLE: GSM789153
# DEBUG:GEOparse:SAMPLE: GSM789153
# 03-Sep-2024 05:54:11 DEBUG GEOparse - SAMPLE: GSM789154
# DEBUG:GEOparse:SAMPLE: GSM789154
# 03-Sep-2024 05:54:12 DEBUG GEOparse - SAMPLE: GSM789155
# DEBUG:GEOparse:SAMPLE: GSM789155
# 03-Sep-2024 05:54:12 DEBUG GEOparse - SAMPLE: GSM789156
# DEBUG:GEOparse:SAMPLE: GSM789156
# 03-Sep-2024 05:54:12 DEBUG GEOparse - SAMPLE: GSM789157
# DEBUG:GEOparse:SAMPLE: GSM789157
# 03-Sep-2024 05:54:13 DEBUG GEOparse - SAMPLE: GSM789158
# DEBUG:GEOparse:SAMPLE: GSM789158
# 03-Sep-2024 05:54:13 DEBUG GEOparse - SAMPLE: GSM789159
# DEBUG:GEOparse:SAMPLE: GSM789159
# 03-Sep-2024 05:54:14 DEBUG GEOparse - SAMPLE: GSM789160
# DEBUG:GEOparse:SAMPLE: GSM789160
# 03-Sep-2024 05:54:14 DEBUG GEOparse - SAMPLE: GSM789161
# DEBUG:GEOparse:SAMPLE: GSM789161
# 03-Sep-2024 05:54:15 DEBUG GEOparse - SAMPLE: GSM789162
# DEBUG:GEOparse:SAMPLE: GSM789162
# 03-Sep-2024 05:54:15 DEBUG GEOparse - SAMPLE: GSM789163
# DEBUG:GEOparse:SAMPLE: GSM789163
# 03-Sep-2024 05:54:16 DEBUG GEOparse - SAMPLE: GSM789164
# DEBUG:GEOparse:SAMPLE: GSM789164
# 03-Sep-2024 05:54:16 DEBUG GEOparse - SAMPLE: GSM789165
# DEBUG:GEOparse:SAMPLE: GSM789165
# 03-Sep-2024 05:54:16 DEBUG GEOparse - SAMPLE: GSM789166
# DEBUG:GEOparse:SAMPLE: GSM789166
# 03-Sep-2024 05:54:17 DEBUG GEOparse - SAMPLE: GSM789167
# DEBUG:GEOparse:SAMPLE: GSM789167
# 03-Sep-2024 05:54:17 DEBUG GEOparse - SAMPLE: GSM789168
# DEBUG:GEOparse:SAMPLE: GSM789168
# 03-Sep-2024 05:54:17 DEBUG GEOparse - SAMPLE: GSM789169
# DEBUG:GEOparse:SAMPLE: GSM789169
# 03-Sep-2024 05:54:18 DEBUG GEOparse - SAMPLE: GSM789170
# DEBUG:GEOparse:SAMPLE: GSM789170
# 03-Sep-2024 05:54:18 DEBUG GEOparse - SAMPLE: GSM789171
# DEBUG:GEOparse:SAMPLE: GSM789171
# 03-Sep-2024 05:54:18 DEBUG GEOparse - SAMPLE: GSM789172
# DEBUG:GEOparse:SAMPLE: GSM789172
# 03-Sep-2024 05:54:19 DEBUG GEOparse - SAMPLE: GSM789173
# DEBUG:GEOparse:SAMPLE: GSM789173
# 03-Sep-2024 05:54:19 DEBUG GEOparse - SAMPLE: GSM789174
# DEBUG:GEOparse:SAMPLE: GSM789174
# 03-Sep-2024 05:54:19 DEBUG GEOparse - SAMPLE: GSM789175
# DEBUG:GEOparse:SAMPLE: GSM789175
# 03-Sep-2024 05:54:20 DEBUG GEOparse - SAMPLE: GSM789176
# DEBUG:GEOparse:SAMPLE: GSM789176
# 03-Sep-2024 05:54:20 DEBUG GEOparse - SAMPLE: GSM789177
# DEBUG:GEOparse:SAMPLE: GSM789177
# 03-Sep-2024 05:54:20 DEBUG GEOparse - SAMPLE: GSM789178
# DEBUG:GEOparse:SAMPLE: GSM789178
# 03-Sep-2024 05:54:20 DEBUG GEOparse - SAMPLE: GSM789179
# DEBUG:GEOparse:SAMPLE: GSM789179
# 03-Sep-2024 05:54:21 DEBUG GEOparse - SAMPLE: GSM789180
# DEBUG:GEOparse:SAMPLE: GSM789180
# 03-Sep-2024 05:54:21 DEBUG GEOparse - SAMPLE: GSM789181
# DEBUG:GEOparse:SAMPLE: GSM789181

# %% [markdown]
# ###Explore the platform table(GPL)

# %%
# Explore the metadata
print("Metadata:")
for key, value in soft_file.metadata.items():
    print(f"{key}: {value}")
# Out:
# Metadata:
# title: ['Expression data for Nonalcoholic fatty liver disease patients']
# geo_accession: ['GSE49541']
# status: ['Public on Aug 30 2013']
# submission_date: ['Aug 05 2013']
# last_update_date: ['Mar 25 2019']
# pubmed_id: ['23913408', '23916847']
# summary: ['Nonalcoholic fatty liver disease represents a spectrum of pathology that ranges from benign steatosis to potentially-progressive steatohepatitis and affects more than 30% of US adults. Advanced NAFLD is associated with increased morbidity and mortality from cirrhosis, primary liver cancer, cardiovascular disease and extrahepatic cancers.', 'Accurate identification of patients at risk for advanced NAFLD is challenging.  The aims of this study were to define the liver gene expression patterns that distinguish mild from advanced NAFLD and to develop a gene expression profile associated with advanced NAFLD.']
# overall_design: ['We analyzed total RNA from 72 patients with NAFLD (40 with mild NAFLD, fibrosis stage 0-1 and 32 with advanced NAFLD, fibrosis stage 3-4) and developed a gene profile associated with advanced NAFLD.']
# type: ['Expression profiling by array']
# contributor: ['Cynthia,,Moylan', 'Anna,M,Diehl']
# sample_id: ['GSM789110', 'GSM789111', 'GSM789112', 'GSM789113', 'GSM789114', 'GSM789115', 'GSM789116', 'GSM789117', 'GSM789118', 'GSM789119', 'GSM789120', 'GSM789121', 'GSM789122', 'GSM789123', 'GSM789124', 'GSM789125', 'GSM789126', 'GSM789127', 'GSM789128', 'GSM789129', 'GSM789130', 'GSM789131', 'GSM789132', 'GSM789133', 'GSM789134', 'GSM789135', 'GSM789136', 'GSM789137', 'GSM789138', 'GSM789139', 'GSM789140', 'GSM789141', 'GSM789142', 'GSM789143', 'GSM789144', 'GSM789145', 'GSM789146', 'GSM789147', 'GSM789148', 'GSM789149', 'GSM789150', 'GSM789151', 'GSM789152', 'GSM789153', 'GSM789154', 'GSM789155', 'GSM789156', 'GSM789157', 'GSM789158', 'GSM789159', 'GSM789160', 'GSM789161', 'GSM789162', 'GSM789163', 'GSM789164', 'GSM789165', 'GSM789166', 'GSM789167', 'GSM789168', 'GSM789169', 'GSM789170', 'GSM789171', 'GSM789172', 'GSM789173', 'GSM789174', 'GSM789175', 'GSM789176', 'GSM789177', 'GSM789178', 'GSM789179', 'GSM789180', 'GSM789181']
# contact_name: ['Cynthia,,Moylan']
# contact_email: ['cynthia.moylan@duke.edu']
# contact_department: ['Gastroenterology']
# contact_institute: ['Duke University Medical Center']
# contact_address: ['595 LaSalle Street, GSRB1, DUMC 3256']
# contact_city: ['Durham']
# contact_state: ['NC']
# contact_zip/postal_code: ['27710']
# contact_country: ['USA']
# supplementary_file: ['ftp://ftp.ncbi.nlm.nih.gov/geo/series/GSE49nnn/GSE49541/suppl/GSE49541_RAW.tar']
# platform_id: ['GPL570']
# platform_taxid: ['9606']
# sample_taxid: ['9606']
# relation: ['SubSeries of: GSE31803', 'BioProject: https://www.ncbi.nlm.nih.gov/bioproject/PRJNA214553']

# %%
for gsm_name, gsm in soft_file.gsms.items():
    print(f"GSM Name: {gsm_name}")
    # Access the GPL platform associated with this GSM
    gpl_name = gsm.metadata['platform_id'][0]
    gpl = soft_file.gpls[gpl_name]
    print(gpl.table.head())
# Out:
# GSM Name: GSM789110
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789111
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789112
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789113
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789114
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789115
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789116
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789117
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789118
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789119
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789120
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789121
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789122
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789123
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789124
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789125
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# ...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789177
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789178
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789179
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789180
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...
# GSM Name: GSM789181
#           ID  GB_ACC SPOT_ID Species Scientific Name Annotation Date  \
# 0  1007_s_at  U48705     NaN            Homo sapiens     Oct 6, 2014
# 1    1053_at  M87338     NaN            Homo sapiens     Oct 6, 2014
# 2     117_at  X51757     NaN            Homo sapiens     Oct 6, 2014
# 3     121_at  X69699     NaN            Homo sapiens     Oct 6, 2014
# 4  1255_g_at  L36861     NaN            Homo sapiens     Oct 6, 2014
#
#        Sequence Type                  Sequence Source  \
# 0  Exemplar sequence  Affymetrix Proprietary Database
# 1  Exemplar sequence                          GenBank
# 2  Exemplar sequence  Affymetrix Proprietary Database
# 3  Exemplar sequence                          GenBank
# 4  Exemplar sequence  Affymetrix Proprietary Database
#
#                                   Target Description Representative Public ID  \
# 0  U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...                   U48705
# 1  M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...                   M87338
# 2  X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...                   X51757
# 3  X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...                   X69699
# 4  L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...                   L36861
#
#                                           Gene Title       Gene Symbol  \
# 0  discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1        replication factor C (activator 1) 2, 40kDa              RFC2
# 2               heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                       paired box 8              PAX8
# 4            guanylate cyclase activator 1A (retina)            GUCA1A
#
#       ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0  780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1               5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2               3310                                          NM_002155
# 3               7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4               2978                         NM_000409 /// XM_006715073
#
#                     Gene Ontology Biological Process  \
# 0  0001558 // regulation of cell growth // inferr...
# 1  0000278 // mitotic cell cycle // traceable aut...
# 2  0000902 // cell morphogenesis // inferred from...
# 3  0001655 // urogenital system development // in...
# 4  0007165 // signal transduction // non-traceabl...
#
#                     Gene Ontology Cellular Component  \
# 0  0005576 // extracellular region // inferred fr...
# 1  0005634 // nucleus // inferred from electronic...
# 2  0005737 // cytoplasm // inferred from direct a...
# 3  0005634 // nucleus // inferred from direct ass...
# 4  0001750 // photoreceptor outer segment // infe...
#
#                     Gene Ontology Molecular Function
# 0  0000166 // nucleotide binding // inferred from...
# 1  0000166 // nucleotide binding // inferred from...
# 2  0000166 // nucleotide binding // inferred from...
# 3  0000979 // RNA polymerase II core promoter seq...
# 4  0005509 // calcium ion binding // inferred fro...

# %%
print(gsm.metadata.keys())
# Out:
# dict_keys(['title', 'geo_accession', 'status', 'submission_date', 'last_update_date', 'type', 'channel_count', 'source_name_ch1', 'organism_ch1', 'taxid_ch1', 'characteristics_ch1', 'molecule_ch1', 'extract_protocol_ch1', 'label_ch1', 'label_protocol_ch1', 'hyb_protocol', 'scan_protocol', 'description', 'data_processing', 'platform_id', 'contact_name', 'contact_email', 'contact_department', 'contact_institute', 'contact_address', 'contact_city', 'contact_state', 'contact_zip/postal_code', 'contact_country', 'supplementary_file', 'series_id', 'data_row_count'])

# %% [markdown]
# ###Explore the samples (GSM)

# %%
for gsm_name, gsm in soft_file.gsms.items():
    print(f"GSM Name: {gsm_name}")
    print(gsm.table.head())
# Out:
# GSM Name: GSM789110
#       ID_REF  VALUE
# 0  1007_s_at  5.043
# 1    1053_at  4.993
# 2     117_at  2.367
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789111
#       ID_REF  VALUE
# 0  1007_s_at  4.739
# 1    1053_at  4.996
# 2     117_at  2.379
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789112
#       ID_REF  VALUE
# 0  1007_s_at  4.728
# 1    1053_at  5.056
# 2     117_at  2.369
# 3     121_at  3.069
# 4  1255_g_at  2.358
# GSM Name: GSM789113
#       ID_REF  VALUE
# 0  1007_s_at  4.480
# 1    1053_at  4.987
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789114
#       ID_REF  VALUE
# 0  1007_s_at  4.479
# 1    1053_at  4.707
# 2     117_at  2.476
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789115
#       ID_REF  VALUE
# 0  1007_s_at  5.410
# 1    1053_at  4.987
# 2     117_at  2.380
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789116
#       ID_REF  VALUE
# 0  1007_s_at  4.435
# 1    1053_at  4.728
# 2     117_at  2.434
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789117
#       ID_REF  VALUE
# 0  1007_s_at  4.424
# 1    1053_at  4.905
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789118
#       ID_REF  VALUE
# 0  1007_s_at  4.624
# 1    1053_at  4.987
# 2     117_at  2.510
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789119
#       ID_REF  VALUE
# 0  1007_s_at  4.568
# 1    1053_at  4.987
# 2     117_at  2.369
# 3     121_at  3.076
# 4  1255_g_at  2.358
# GSM Name: GSM789120
#       ID_REF  VALUE
# 0  1007_s_at  4.205
# 1    1053_at  5.079
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789121
#       ID_REF  VALUE
# 0  1007_s_at  4.765
# 1    1053_at  5.323
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789122
#       ID_REF  VALUE
# 0  1007_s_at  4.472
# 1    1053_at  5.043
# 2     117_at  2.467
# 3     121_at  3.315
# 4  1255_g_at  2.358
# GSM Name: GSM789123
#       ID_REF  VALUE
# 0  1007_s_at  4.613
# 1    1053_at  4.943
# 2     117_at  2.381
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789124
#       ID_REF  VALUE
# 0  1007_s_at  4.753
# 1    1053_at  4.135
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789125
#       ID_REF  VALUE
# 0  1007_s_at  4.388
# 1    1053_at  5.513
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789126
#       ID_REF  VALUE
# 0  1007_s_at  3.960
# 1    1053_at  5.200
# 2     117_at  2.559
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789127
#       ID_REF  VALUE
# 0  1007_s_at  5.121
# 1    1053_at  4.219
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789128
#       ID_REF  VALUE
# 0  1007_s_at  4.328
# 1    1053_at  5.083
# 2     117_at  2.369
# 3     121_at  3.108
# 4  1255_g_at  2.358
# GSM Name: GSM789129
#       ID_REF  VALUE
# 0  1007_s_at  4.257
# 1    1053_at  4.750
# 2     117_at  2.467
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789130
#       ID_REF  VALUE
# 0  1007_s_at  4.788
# 1    1053_at  4.987
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789131
#       ID_REF  VALUE
# 0  1007_s_at  3.919
# 1    1053_at  5.043
# 2     117_at  2.547
# 3     121_at  3.076
# 4  1255_g_at  2.358
# GSM Name: GSM789132
#       ID_REF  VALUE
# 0  1007_s_at  4.858
# 1    1053_at  5.053
# 2     117_at  2.369
# 3     121_at  3.352
# 4  1255_g_at  2.358
# GSM Name: GSM789133
#       ID_REF  VALUE
# 0  1007_s_at  4.230
# 1    1053_at  5.027
# 2     117_at  2.369
# 3     121_at  3.348
# 4  1255_g_at  2.358
# GSM Name: GSM789134
#       ID_REF  VALUE
# 0  1007_s_at  4.130
# 1    1053_at  4.595
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789135
#       ID_REF  VALUE
# 0  1007_s_at  4.472
# 1    1053_at  5.028
# 2     117_at  2.370
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789136
#       ID_REF  VALUE
# 0  1007_s_at  4.472
# 1    1053_at  4.833
# 2     117_at  2.369
# 3     121_at  3.085
# 4  1255_g_at  2.358
# GSM Name: GSM789137
#       ID_REF  VALUE
# 0  1007_s_at  4.486
# 1    1053_at  4.987
# 2     117_at  2.367
# 3     121_at  3.055
# 4  1255_g_at  2.358
# GSM Name: GSM789138
#       ID_REF  VALUE
# 0  1007_s_at  5.026
# 1    1053_at  4.837
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789139
#       ID_REF  VALUE
# 0  1007_s_at  5.045
# 1    1053_at  5.133
# 2     117_at  2.592
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789140
#       ID_REF  VALUE
# 0  1007_s_at  4.826
# 1    1053_at  4.689
# 2     117_at  2.367
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789141
#       ID_REF  VALUE
# 0  1007_s_at  4.449
# 1    1053_at  5.003
# 2     117_at  2.367
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789142
#       ID_REF  VALUE
# 0  1007_s_at  4.166
# 1    1053_at  4.668
# 2     117_at  2.367
# 3     121_at  3.096
# 4  1255_g_at  2.358
# GSM Name: GSM789143
#       ID_REF  VALUE
# 0  1007_s_at  4.472
# 1    1053_at  5.076
# 2     117_at  2.384
# 3     121_at  3.277
# 4  1255_g_at  2.358
# GSM Name: GSM789144
#       ID_REF  VALUE
# 0  1007_s_at  4.092
# 1    1053_at  4.508
# 2     117_at  2.416
# 3     121_at  3.090
# 4  1255_g_at  2.358
# GSM Name: GSM789145
#       ID_REF  VALUE
# 0  1007_s_at  4.351
# 1    1053_at  5.230
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789146
#       ID_REF  VALUE
# 0  1007_s_at  4.495
# 1    1053_at  4.988
# 2     117_at  2.413
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789147
#       ID_REF  VALUE
# 0  1007_s_at  4.472
# 1    1053_at  4.749
# 2     117_at  2.403
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789148
#       ID_REF  VALUE
# 0  1007_s_at  4.466
# 1    1053_at  4.939
# 2     117_at  2.369
# 3     121_at  3.042
# 4  1255_g_at  2.358
# GSM Name: GSM789149
#       ID_REF  VALUE
# 0  1007_s_at  4.493
# 1    1053_at  5.169
# 2     117_at  2.388
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789150
#       ID_REF  VALUE
# 0  1007_s_at  4.231
# 1    1053_at  4.987
# 2     117_at  2.369
# 3     121_at  3.182
# 4  1255_g_at  2.358
# GSM Name: GSM789151
#       ID_REF  VALUE
# 0  1007_s_at  4.461
# 1    1053_at  5.284
# 2     117_at  2.369
# 3     121_at  3.091
# 4  1255_g_at  2.358
# GSM Name: GSM789152
#       ID_REF  VALUE
# 0  1007_s_at  6.131
# 1    1053_at  3.750
# 2     117_at  2.369
# 3     121_at  3.054
# 4  1255_g_at  2.358
# GSM Name: GSM789153
#       ID_REF  VALUE
# 0  1007_s_at  4.617
# 1    1053_at  4.594
# 2     117_at  2.511
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789154
#       ID_REF  VALUE
# 0  1007_s_at  4.136
# 1    1053_at  4.008
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789155
#       ID_REF  VALUE
# 0  1007_s_at  4.548
# 1    1053_at  4.261
# 2     117_at  2.368
# 3     121_at  3.069
# 4  1255_g_at  2.358
# GSM Name: GSM789156
#       ID_REF  VALUE
# 0  1007_s_at  4.604
# 1    1053_at  5.050
# 2     117_at  2.373
# 3     121_at  3.191
# 4  1255_g_at  2.358
# GSM Name: GSM789157
#       ID_REF  VALUE
# 0  1007_s_at  4.835
# 1    1053_at  4.918
# 2     117_at  2.369
# 3     121_at  3.128
# 4  1255_g_at  2.358
# GSM Name: GSM789158
#       ID_REF  VALUE
# 0  1007_s_at  4.355
# 1    1053_at  5.357
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789159
#       ID_REF  VALUE
# 0  1007_s_at  4.503
# 1    1053_at  4.987
# 2     117_at  2.372
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789160
#       ID_REF  VALUE
# 0  1007_s_at  4.273
# 1    1053_at  5.006
# 2     117_at  2.368
# 3     121_at  3.117
# 4  1255_g_at  2.358
# GSM Name: GSM789161
#       ID_REF  VALUE
# 0  1007_s_at  4.168
# 1    1053_at  5.145
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789162
#       ID_REF  VALUE
# 0  1007_s_at  4.129
# 1    1053_at  5.162
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789163
#       ID_REF  VALUE
# 0  1007_s_at  4.787
# 1    1053_at  4.987
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789164
#       ID_REF  VALUE
# 0  1007_s_at  4.787
# 1    1053_at  4.706
# 2     117_at  2.618
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789165
#       ID_REF  VALUE
# 0  1007_s_at  4.361
# 1    1053_at  4.988
# 2     117_at  2.405
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789166
#       ID_REF  VALUE
# 0  1007_s_at  4.424
# 1    1053_at  5.045
# 2     117_at  2.378
# 3     121_at  3.110
# 4  1255_g_at  2.358
# GSM Name: GSM789167
#       ID_REF  VALUE
# 0  1007_s_at  4.472
# 1    1053_at  4.913
# 2     117_at  2.392
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789168
#       ID_REF  VALUE
# 0  1007_s_at  4.279
# 1    1053_at  5.178
# 2     117_at  2.629
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789169
#       ID_REF  VALUE
# 0  1007_s_at  4.349
# 1    1053_at  4.997
# 2     117_at  2.399
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789170
#       ID_REF  VALUE
# 0  1007_s_at  4.444
# 1    1053_at  4.722
# 2     117_at  2.641
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789171
#       ID_REF  VALUE
# 0  1007_s_at  4.751
# 1    1053_at  5.210
# 2     117_at  2.451
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789172
#       ID_REF  VALUE
# 0  1007_s_at  4.145
# 1    1053_at  5.220
# 2     117_at  2.367
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789173
#       ID_REF  VALUE
# 0  1007_s_at  4.664
# 1    1053_at  4.987
# 2     117_at  2.427
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789174
#       ID_REF  VALUE
# 0  1007_s_at  4.615
# 1    1053_at  4.991
# 2     117_at  2.373
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789175
#       ID_REF  VALUE
# 0  1007_s_at  4.462
# 1    1053_at  4.987
# 2     117_at  2.365
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789176
#       ID_REF  VALUE
# 0  1007_s_at  4.780
# 1    1053_at  4.921
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789177
#       ID_REF  VALUE
# 0  1007_s_at  4.368
# 1    1053_at  4.703
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789178
#       ID_REF  VALUE
# 0  1007_s_at  4.182
# 1    1053_at  4.987
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789179
#       ID_REF  VALUE
# 0  1007_s_at  4.530
# 1    1053_at  5.178
# 2     117_at  2.369
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789180
#       ID_REF  VALUE
# 0  1007_s_at  4.476
# 1    1053_at  4.980
# 2     117_at  2.383
# 3     121_at  3.087
# 4  1255_g_at  2.358
# GSM Name: GSM789181
#       ID_REF  VALUE
# 0  1007_s_at  4.225
# 1    1053_at  4.526
# 2     117_at  2.366
# 3     121_at  3.081
# 4  1255_g_at  2.358

# %% [markdown]
# ###Inspect sample metadata

# %%
print(soft_file.gsms['GSM789136'].metadata)
# Out:
# {'title': ['NAFLD liver biopsy tissue 15361'], 'geo_accession': ['GSM789136'], 'status': ['Public on Aug 30 2013'], 'submission_date': ['Aug 31 2011'], 'last_update_date': ['Aug 30 2013'], 'type': ['RNA'], 'channel_count': ['1'], 'source_name_ch1': ['NAFLD liver biopsy tissue'], 'organism_ch1': ['Homo sapiens'], 'taxid_ch1': ['9606'], 'characteristics_ch1': ['Stage: mild (fibrosis stage 0-1)', 'tissue: liver'], 'molecule_ch1': ['total RNA'], 'extract_protocol_ch1': ["Qiagen Micro Kit according to manufacturer's instructions"], 'label_ch1': ['biotin'], 'label_protocol_ch1': ['Ambion MessageAmp Premier as described by the manufacturer'], 'hyb_protocol': ['Affymetrix GeneChip  hybridization Oven 645'], 'scan_protocol': ['Affymetrix GeneChip Scanner 7G'], 'description': ['Gene expression data from mild NAFLD patient'], 'data_processing': ['GC-RMA'], 'platform_id': ['GPL570'], 'contact_name': ['Cynthia,,Moylan'], 'contact_email': ['cynthia.moylan@duke.edu'], 'contact_department': ['Gastroenterology'], 'contact_institute': ['Duke University Medical Center'], 'contact_address': ['595 LaSalle Street, GSRB1, DUMC 3256'], 'contact_city': ['Durham'], 'contact_state': ['NC'], 'contact_zip/postal_code': ['27710'], 'contact_country': ['USA'], 'supplementary_file': ['ftp://ftp.ncbi.nlm.nih.gov/geo/samples/GSM789nnn/GSM789136/suppl/GSM789136.CEL.gz'], 'series_id': ['GSE31803', 'GSE49541'], 'data_row_count': ['54675']}

# %% [markdown]
# ###Data handling libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###Data visualization libaries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###Preprocessing libaries

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import label_binarize
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ###Feature Selection library

# %%
from sklearn.feature_selection import mutual_info_classif

# %% [markdown]
# ###Classification libraries

# %%
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ### Performance Metrics libraries

# %%
from sklearn.metrics import balanced_accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ###Initialize lists to store sample names, expression data and stages

# %%
sample_names = []
expression_data = []
stages = []

# %% [markdown]
# ###Iterate through all samples (GSM) in the soft file
#
# This code iterates through each sample in a GEO Soft file, appending the sample names and corresponding gene expression values to separate lists. It also extracts the 'Stage' information from the metadata and appends this to a list. The extracted data is then stored for further analysis or processing.

# %%
for gsm_name, gsm in soft_file.gsms.items():
  #append the sample name
  sample_names.append(gsm_name)
  #append the expression values (list of values corresponding to each probe ID)
  expression_data.append(gsm.table['VALUE'].values)
  #extract and append the 'Stage' from the metadata
  characteristics = gsm.metadata.get('characteristics_ch1', [])
  # print(f"Characteristics for {gsm_name}: {characteristics}")
  stage_info = None
  for item in characteristics:
    print(item)
    if 'Stage' in item:

      stage_info = item.split(': ')[-1]
      break
  stages.append(stage_info)
# Out:
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: mild (fibrosis stage 0-1)
# Stage: mild (fibrosis stage 0-1)
# Stage: advanced (fibrosis stage 3-4)
# Stage: advanced (fibrosis stage 3-4)

# %%
stages
# Out:
# ['advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'mild (fibrosis stage 0-1)',
#  'mild (fibrosis stage 0-1)',
#  'advanced (fibrosis stage 3-4)',
#  'advanced (fibrosis stage 3-4)']

# %% [markdown]
# ###Convert expression data to a DataFrame

# %%
df = pd.DataFrame(expression_data, index=sample_names)
df.head()
# Out:
#            0      1      2      3      4      5      6      7      8      \
# GSM789110  5.043  4.993  2.367  3.087  2.358  2.573  2.690  2.358  6.594
# GSM789111  4.739  4.996  2.379  3.087  2.358  2.825  2.745  2.358  7.451
# GSM789112  4.728  5.056  2.369  3.069  2.358  2.638  2.694  2.358  6.626
# GSM789113  4.480  4.987  2.369  3.087  2.358  2.638  3.326  2.358  6.203
# GSM789114  4.479  4.707  2.476  3.087  2.358  2.592  2.588  2.358  5.661
#
#             9      ...   54665   54666   54667   54668  54669  54670  54671  \
# GSM789110  13.436  ...  13.163  11.954  14.592  14.061  8.962  6.886  8.040
# GSM789111  13.778  ...  13.641  12.551  14.833  14.336  7.382  4.178  5.769
# GSM789112  13.568  ...  13.714  12.669  14.863  14.429  8.737  7.003  7.925
# GSM789113  13.767  ...  13.053  12.006  14.500  13.898  8.774  6.608  7.858
# GSM789114  13.439  ...  13.565  12.459  14.848  14.362  8.966  5.333  7.427
#
#            54672  54673  54674
# GSM789110  2.358  2.358  2.358
# GSM789111  2.358  2.358  2.358
# GSM789112  2.358  2.358  2.358
# GSM789113  2.358  2.358  2.358
# GSM789114  2.358  2.358  2.358
#
# [5 rows x 54675 columns]

# %% [markdown]
# ###Add the probe IDs as column headers

# %%
df.columns = gsm.table['ID_REF']
df.head()
# Out:
# ID_REF     1007_s_at  1053_at  117_at  121_at  1255_g_at  1294_at  1316_at  \
# GSM789110      5.043    4.993   2.367   3.087      2.358    2.573    2.690
# GSM789111      4.739    4.996   2.379   3.087      2.358    2.825    2.745
# GSM789112      4.728    5.056   2.369   3.069      2.358    2.638    2.694
# GSM789113      4.480    4.987   2.369   3.087      2.358    2.638    3.326
# GSM789114      4.479    4.707   2.476   3.087      2.358    2.592    2.588
#
# ID_REF     1320_at  1405_i_at  1431_at  ...  AFFX-r2-Ec-bioD-3_at  \
# GSM789110    2.358      6.594   13.436  ...                13.163
# GSM789111    2.358      7.451   13.778  ...                13.641
# GSM789112    2.358      6.626   13.568  ...                13.714
# GSM789113    2.358      6.203   13.767  ...                13.053
# GSM789114    2.358      5.661   13.439  ...                13.565
#
# ID_REF     AFFX-r2-Ec-bioD-5_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# GSM789110                11.954               14.592               14.061
# GSM789111                12.551               14.833               14.336
# GSM789112                12.669               14.863               14.429
# GSM789113                12.006               14.500               13.898
# GSM789114                12.459               14.848               14.362
#
# ID_REF     AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  \
# GSM789110           8.962           6.886           8.040            2.358
# GSM789111           7.382           4.178           5.769            2.358
# GSM789112           8.737           7.003           7.925            2.358
# GSM789113           8.774           6.608           7.858            2.358
# GSM789114           8.966           5.333           7.427            2.358
#
# ID_REF     AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# GSM789110            2.358            2.358
# GSM789111            2.358            2.358
# GSM789112            2.358            2.358
# GSM789113            2.358            2.358
# GSM789114            2.358            2.358
#
# [5 rows x 54675 columns]

# %%
df.shape
# Out:
# (72, 54675)

# %% [markdown]
# ###Check for missing values in each column

# %%
datanul = df.isnull().sum()
datanul
# Out:
# ID_REF
# 1007_s_at          0
# 1053_at            0
# 117_at             0
# 121_at             0
# 1255_g_at          0
#                   ..
# AFFX-ThrX-5_at     0
# AFFX-ThrX-M_at     0
# AFFX-TrpnX-3_at    0
# AFFX-TrpnX-5_at    0
# AFFX-TrpnX-M_at    0
# Length: 54675, dtype: int64

# %% [markdown]
# ###No missing values but if there are missing values run this code:

# %%
g = [i for i in datanul.index if datanul[i] > 0]
print('columns with missing values: %d' % len(g))
print("Genes with missing values:", g)
# Out:
# columns with missing values: 0
# Genes with missing values: []

# %%
#Remove gene with missing values
df_cleaned = df.drop(columns=g)

# %%
#Double check gene removal
datanul_cleaned = df_cleaned.isnull().sum()
datanul_cleaned
# Out:
# ID_REF
# 1007_s_at          0
# 1053_at            0
# 117_at             0
# 121_at             0
# 1255_g_at          0
#                   ..
# AFFX-ThrX-5_at     0
# AFFX-ThrX-M_at     0
# AFFX-TrpnX-3_at    0
# AFFX-TrpnX-5_at    0
# AFFX-TrpnX-M_at    0
# Length: 54675, dtype: int64

# %% [markdown]
# ###Add 'Stage' information as a new column in the DataFrame

# %%
print(f"Number of samples (sample_names): {len(sample_names)}")
print(f"Number of expression arrays (expression_data): {len(expression_data)}")
print(f"Number of stages (stages): {len(stages)}")
# Out:
# Number of samples (sample_names): 72
# Number of expression arrays (expression_data): 72
# Number of stages (stages): 72

# %%
print(sample_names[:10])
print(stages[:10])
# Out:
# ['GSM789110', 'GSM789111', 'GSM789112', 'GSM789113', 'GSM789114', 'GSM789115', 'GSM789116', 'GSM789117', 'GSM789118', 'GSM789119']
# ['advanced (fibrosis stage 3-4)', 'advanced (fibrosis stage 3-4)', 'mild (fibrosis stage 0-1)', 'mild (fibrosis stage 0-1)', 'mild (fibrosis stage 0-1)', 'advanced (fibrosis stage 3-4)', 'mild (fibrosis stage 0-1)', 'mild (fibrosis stage 0-1)', 'mild (fibrosis stage 0-1)', 'advanced (fibrosis stage 3-4)']

# %%
df['Stage'] = stages
df.head()
# Out:
# ID_REF     1007_s_at  1053_at  117_at  121_at  1255_g_at  1294_at  1316_at  \
# GSM789110      5.043    4.993   2.367   3.087      2.358    2.573    2.690
# GSM789111      4.739    4.996   2.379   3.087      2.358    2.825    2.745
# GSM789112      4.728    5.056   2.369   3.069      2.358    2.638    2.694
# GSM789113      4.480    4.987   2.369   3.087      2.358    2.638    3.326
# GSM789114      4.479    4.707   2.476   3.087      2.358    2.592    2.588
#
# ID_REF     1320_at  1405_i_at  1431_at  ...  AFFX-r2-Ec-bioD-5_at  \
# GSM789110    2.358      6.594   13.436  ...                11.954
# GSM789111    2.358      7.451   13.778  ...                12.551
# GSM789112    2.358      6.626   13.568  ...                12.669
# GSM789113    2.358      6.203   13.767  ...                12.006
# GSM789114    2.358      5.661   13.439  ...                12.459
#
# ID_REF     AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  AFFX-ThrX-3_at  \
# GSM789110               14.592               14.061           8.962
# GSM789111               14.833               14.336           7.382
# GSM789112               14.863               14.429           8.737
# GSM789113               14.500               13.898           8.774
# GSM789114               14.848               14.362           8.966
#
# ID_REF     AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  AFFX-TrpnX-5_at  \
# GSM789110           6.886           8.040            2.358            2.358
# GSM789111           4.178           5.769            2.358            2.358
# GSM789112           7.003           7.925            2.358            2.358
# GSM789113           6.608           7.858            2.358            2.358
# GSM789114           5.333           7.427            2.358            2.358
#
# ID_REF     AFFX-TrpnX-M_at                          Stage
# GSM789110            2.358  advanced (fibrosis stage 3-4)
# GSM789111            2.358  advanced (fibrosis stage 3-4)
# GSM789112            2.358      mild (fibrosis stage 0-1)
# GSM789113            2.358      mild (fibrosis stage 0-1)
# GSM789114            2.358      mild (fibrosis stage 0-1)
#
# [5 rows x 54676 columns]

# %% [markdown]
# ###Separate the features and target variable

# %%
x = df.drop(['Stage'], axis=1)
y = df['Stage']

# %%
print(x.shape)
print(y.shape)
# Out:
# (72, 54675)
# (72,)

# %% [markdown]
# ###Encode labels
# Labels are categorical and therefore have to convert them to numeric

# %%
le = LabelEncoder()
y_encoded = le.fit_transform(y)
categorical_label = le.classes_
numerical_label = np.unique(y_encoded)

# %%
categorical_label
# Out:
# array(['advanced (fibrosis stage 3-4)', 'mild (fibrosis stage 0-1)'],
#       dtype=object)

# %%
numerical_label
# Out:
# array([0, 1])

# %% [markdown]
# ##Normalize expression data to a standard range

# %%
min_max_scaler = MinMaxScaler()
x=min_max_scaler.fit_transform(x)

# Convert scaled data back to DataFrame to check statistics
scaled_df = pd.DataFrame(x, columns=df.columns[:-1])  # Use df.columns[:-1] to exclude the 'Stage' column

# %%
# Print the description of the scaled data
#print(scaled_df.describe())

# %% [markdown]
# ###Split data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y_encoded, test_size=0.2, random_state=42)

# %% [markdown]
# ###Autoencoder to reduce x to a latent space
#
# A neural network used for dimensionality reduction, denoising, unsupervised feature learning

# %%
import keras
from keras.layers import Input, Dense
from keras.models import Model

# Define the dimensions of the input and latent space
input_dim = x_train.shape[1]
encoding_dim = 10  # Adjust this depending on how much you want to reduce the dimensionality

# Create input layer
input_layer = Input(shape=(input_dim,))

# Encoder layers
encoded = Dense(64, activation='relu')(input_layer) # first layer has 64 neurons
encoded = Dense(32, activation='relu')(encoded) # Second layer has 32 neurons, relu activation function introduces non-linearity
encoded = Dense(encoding_dim, activation='relu')(encoded)  # Latent space representation

# Decoder layers (for the full autoencoder, not used here)
decoded = Dense(32, activation='relu')(encoded)
decoded = Dense(64, activation='relu')(decoded)
decoded = Dense(input_dim, activation='sigmoid')(decoded)

# Create the encoder model
encoder = Model(input_layer, encoded)

# Train the autoencoder (if you want to train the full autoencoder)
autoencoder = Model(input_layer, decoded)
optimizer = keras.optimizers.Adam(learning_rate=0.001)
autoencoder.compile(optimizer=optimizer, loss='mse')

autoencoder.fit(x_train, x_train, epochs=150, batch_size=32, validation_data=(x, x))

# Encode the data to the latent space
x_train_encoded = encoder.predict(x_train)
x_test_encoded = encoder.predict(x_test)
# Out:
# Epoch 1/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - loss: 0.1505 - val_loss: 0.1499
# Epoch 2/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 588ms/step - loss: 0.1483 - val_loss: 0.1265
# Epoch 3/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 640ms/step - loss: 0.1181 - val_loss: 0.0637
# Epoch 4/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 585ms/step - loss: 0.0578 - val_loss: 0.0368
# Epoch 5/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 497ms/step - loss: 0.0371 - val_loss: 0.0363
# Epoch 6/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 596ms/step - loss: 0.0358 - val_loss: 0.0360
# Epoch 7/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 412ms/step - loss: 0.0360 - val_loss: 0.0348
# Epoch 8/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 489ms/step - loss: 0.0352 - val_loss: 0.0340
# Epoch 9/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 707ms/step - loss: 0.0348 - val_loss: 0.0335
# Epoch 10/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 432ms/step - loss: 0.0336 - val_loss: 0.0328
# Epoch 11/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 446ms/step - loss: 0.0331 - val_loss: 0.0322
# Epoch 12/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 476ms/step - loss: 0.0313 - val_loss: 0.0317
# Epoch 13/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 427ms/step - loss: 0.0307 - val_loss: 0.0314
# Epoch 14/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 686ms/step - loss: 0.0307 - val_loss: 0.0310
# Epoch 15/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 593ms/step - loss: 0.0313 - val_loss: 0.0307
# Epoch 16/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 754ms/step - loss: 0.0310 - val_loss: 0.0305
# Epoch 17/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step - loss: 0.0309 - val_loss: 0.0303
# Epoch 18/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 743ms/step - loss: 0.0306 - val_loss: 0.0301
# Epoch 19/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 674ms/step - loss: 0.0299 - val_loss: 0.0299
# Epoch 20/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - loss: 0.0302 - val_loss: 0.0298
# Epoch 21/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step - loss: 0.0293 - val_loss: 0.0296
# Epoch 22/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 199ms/step - loss: 0.0295 - val_loss: 0.0295
# Epoch 23/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - loss: 0.0298 - val_loss: 0.0293
# Epoch 24/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - loss: 0.0296 - val_loss: 0.0292
# Epoch 25/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 265ms/step - loss: 0.0294 - val_loss: 0.0290
# Epoch 26/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - loss: 0.0289 - val_loss: 0.0288
# Epoch 27/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 205ms/step - loss: 0.0291 - val_loss: 0.0286
# Epoch 28/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - loss: 0.0289 - val_loss: 0.0284
# Epoch 29/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 0.0288 - val_loss: 0.0282
# Epoch 30/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step - loss: 0.0290 - val_loss: 0.0280
# Epoch 31/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - loss: 0.0277 - val_loss: 0.0278
# Epoch 32/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - loss: 0.0280 - val_loss: 0.0277
# Epoch 33/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 196ms/step - loss: 0.0279 - val_loss: 0.0275
# Epoch 34/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step - loss: 0.0279 - val_loss: 0.0274
# Epoch 35/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.0274 - val_loss: 0.0272
# Epoch 36/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 185ms/step - loss: 0.0272 - val_loss: 0.0271
# Epoch 37/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - loss: 0.0272 - val_loss: 0.0269
# Epoch 38/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 351ms/step - loss: 0.0265 - val_loss: 0.0266
# Epoch 39/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 350ms/step - loss: 0.0263 - val_loss: 0.0263
# Epoch 40/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 396ms/step - loss: 0.0270 - val_loss: 0.0260
# Epoch 41/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 366ms/step - loss: 0.0258 - val_loss: 0.0257
# Epoch 42/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 406ms/step - loss: 0.0253 - val_loss: 0.0255
# Epoch 43/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - loss: 0.0255 - val_loss: 0.0251
# Epoch 44/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step - loss: 0.0252 - val_loss: 0.0249
# Epoch 45/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 413ms/step - loss: 0.0251 - val_loss: 0.0248
# Epoch 46/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step - loss: 0.0248 - val_loss: 0.0248
# Epoch 47/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 483ms/step - loss: 0.0243 - val_loss: 0.0247
# Epoch 48/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 405ms/step - loss: 0.0246 - val_loss: 0.0246
# Epoch 49/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 460ms/step - loss: 0.0248 - val_loss: 0.0246
# Epoch 50/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 566ms/step - loss: 0.0238 - val_loss: 0.0246
# Epoch 51/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 395ms/step - loss: 0.0247 - val_loss: 0.0246
# Epoch 52/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 447ms/step - loss: 0.0242 - val_loss: 0.0245
# Epoch 53/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 355ms/step - loss: 0.0245 - val_loss: 0.0245
# Epoch 54/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step - loss: 0.0249 - val_loss: 0.0245
# Epoch 55/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 336ms/step - loss: 0.0245 - val_loss: 0.0245
# Epoch 56/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 280ms/step - loss: 0.0244 - val_loss: 0.0244
# Epoch 57/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - loss: 0.0245 - val_loss: 0.0244
# Epoch 58/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 363ms/step - loss: 0.0241 - val_loss: 0.0244
# Epoch 59/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 339ms/step - loss: 0.0248 - val_loss: 0.0243
# Epoch 60/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step - loss: 0.0238 - val_loss: 0.0243
# Epoch 61/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 242ms/step - loss: 0.0244 - val_loss: 0.0243
# Epoch 62/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - loss: 0.0239 - val_loss: 0.0242
# Epoch 63/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - loss: 0.0236 - val_loss: 0.0242
# Epoch 64/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - loss: 0.0243 - val_loss: 0.0242
# Epoch 65/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 249ms/step - loss: 0.0237 - val_loss: 0.0241
# Epoch 66/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - loss: 0.0243 - val_loss: 0.0241
# Epoch 67/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 244ms/step - loss: 0.0238 - val_loss: 0.0241
# Epoch 68/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step - loss: 0.0240 - val_loss: 0.0240
# Epoch 69/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - loss: 0.0236 - val_loss: 0.0240
# Epoch 70/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step - loss: 0.0240 - val_loss: 0.0239
# Epoch 71/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - loss: 0.0235 - val_loss: 0.0238
# Epoch 72/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - loss: 0.0232 - val_loss: 0.0237
# Epoch 73/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - loss: 0.0233 - val_loss: 0.0237
# Epoch 74/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step - loss: 0.0231 - val_loss: 0.0236
# Epoch 75/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 0.0234 - val_loss: 0.0235
# Epoch 76/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step - loss: 0.0231 - val_loss: 0.0233
# Epoch 77/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step - loss: 0.0234 - val_loss: 0.0232
# Epoch 78/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - loss: 0.0234 - val_loss: 0.0231
# Epoch 79/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step - loss: 0.0226 - val_loss: 0.0229
# Epoch 80/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - loss: 0.0227 - val_loss: 0.0228
# Epoch 81/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step - loss: 0.0226 - val_loss: 0.0226
# Epoch 82/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step - loss: 0.0223 - val_loss: 0.0225
# Epoch 83/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 388ms/step - loss: 0.0220 - val_loss: 0.0224
# Epoch 84/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 347ms/step - loss: 0.0220 - val_loss: 0.0222
# Epoch 85/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 391ms/step - loss: 0.0215 - val_loss: 0.0221
# Epoch 86/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 381ms/step - loss: 0.0215 - val_loss: 0.0221
# Epoch 87/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 374ms/step - loss: 0.0218 - val_loss: 0.0220
# Epoch 88/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - loss: 0.0212 - val_loss: 0.0219
# Epoch 89/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - loss: 0.0213 - val_loss: 0.0219
# Epoch 90/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - loss: 0.0217 - val_loss: 0.0218
# Epoch 91/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step - loss: 0.0213 - val_loss: 0.0218
# Epoch 92/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step - loss: 0.0207 - val_loss: 0.0217
# Epoch 93/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - loss: 0.0215 - val_loss: 0.0216
# Epoch 94/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 229ms/step - loss: 0.0208 - val_loss: 0.0216
# Epoch 95/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - loss: 0.0210 - val_loss: 0.0215
# Epoch 96/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - loss: 0.0211 - val_loss: 0.0214
# Epoch 97/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step - loss: 0.0213 - val_loss: 0.0214
# Epoch 98/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - loss: 0.0204 - val_loss: 0.0213
# Epoch 99/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step - loss: 0.0209 - val_loss: 0.0212
# Epoch 100/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - loss: 0.0206 - val_loss: 0.0211
# Epoch 101/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step - loss: 0.0203 - val_loss: 0.0209
# Epoch 102/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step - loss: 0.0197 - val_loss: 0.0208
# Epoch 103/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 250ms/step - loss: 0.0202 - val_loss: 0.0207
# Epoch 104/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step - loss: 0.0205 - val_loss: 0.0205
# Epoch 105/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - loss: 0.0196 - val_loss: 0.0204
# Epoch 106/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - loss: 0.0199 - val_loss: 0.0203
# Epoch 107/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 253ms/step - loss: 0.0194 - val_loss: 0.0201
# Epoch 108/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 330ms/step - loss: 0.0190 - val_loss: 0.0200
# Epoch 109/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 379ms/step - loss: 0.0193 - val_loss: 0.0199
# Epoch 110/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 382ms/step - loss: 0.0190 - val_loss: 0.0198
# Epoch 111/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 342ms/step - loss: 0.0191 - val_loss: 0.0197
# Epoch 112/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step - loss: 0.0187 - val_loss: 0.0196
# Epoch 113/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step - loss: 0.0190 - val_loss: 0.0196
# Epoch 114/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - loss: 0.0186 - val_loss: 0.0195
# Epoch 115/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - loss: 0.0186 - val_loss: 0.0194
# Epoch 116/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step - loss: 0.0185 - val_loss: 0.0193
# Epoch 117/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step - loss: 0.0186 - val_loss: 0.0192
# Epoch 118/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 466ms/step - loss: 0.0181 - val_loss: 0.0192
# Epoch 119/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 455ms/step - loss: 0.0181 - val_loss: 0.0191
# Epoch 120/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 334ms/step - loss: 0.0180 - val_loss: 0.0190
# Epoch 121/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 2s 676ms/step - loss: 0.0178 - val_loss: 0.0190
# Epoch 122/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 362ms/step - loss: 0.0178 - val_loss: 0.0189
# Epoch 123/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 394ms/step - loss: 0.0178 - val_loss: 0.0188
# Epoch 124/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 433ms/step - loss: 0.0179 - val_loss: 0.0188
# Epoch 125/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 712ms/step - loss: 0.0176 - val_loss: 0.0187
# Epoch 126/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 343ms/step - loss: 0.0176 - val_loss: 0.0187
# Epoch 127/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 361ms/step - loss: 0.0173 - val_loss: 0.0187
# Epoch 128/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 404ms/step - loss: 0.0176 - val_loss: 0.0186
# Epoch 129/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 386ms/step - loss: 0.0172 - val_loss: 0.0185
# Epoch 130/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 384ms/step - loss: 0.0172 - val_loss: 0.0185
# Epoch 131/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 404ms/step - loss: 0.0174 - val_loss: 0.0184
# Epoch 132/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 264ms/step - loss: 0.0174 - val_loss: 0.0183
# Epoch 133/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step - loss: 0.0169 - val_loss: 0.0183
# Epoch 134/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 254ms/step - loss: 0.0173 - val_loss: 0.0182
# Epoch 135/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - loss: 0.0172 - val_loss: 0.0181
# Epoch 136/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step - loss: 0.0169 - val_loss: 0.0181
# Epoch 137/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step - loss: 0.0168 - val_loss: 0.0181
# Epoch 138/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 651ms/step - loss: 0.0167 - val_loss: 0.0180
# Epoch 139/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 235ms/step - loss: 0.0166 - val_loss: 0.0180
# Epoch 140/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 238ms/step - loss: 0.0164 - val_loss: 0.0179
# Epoch 141/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - loss: 0.0165 - val_loss: 0.0178
# Epoch 142/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 265ms/step - loss: 0.0161 - val_loss: 0.0178
# Epoch 143/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - loss: 0.0161 - val_loss: 0.0178
# Epoch 144/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - loss: 0.0165 - val_loss: 0.0177
# Epoch 145/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0160 - val_loss: 0.0176
# Epoch 146/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - loss: 0.0160 - val_loss: 0.0176
# Epoch 147/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.0164 - val_loss: 0.0175
# Epoch 148/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - loss: 0.0158 - val_loss: 0.0174
# Epoch 149/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 256ms/step - loss: 0.0160 - val_loss: 0.0174
# Epoch 150/150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 365ms/step - loss: 0.0159 - val_loss: 0.0173
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step

# %%
# Evaluate the reconstruction loss on the test set
reconstruction_loss = autoencoder.evaluate(x_test, x_test, verbose=0)
print("Reconstruction Loss:", reconstruction_loss)
# Out:
# Reconstruction Loss: 0.023721612989902496

# %% [markdown]
# ###Random Forest without autoencoder

# %%
RF = OneVsRestClassifier(RandomForestClassifier(max_features=.2))
RF.fit(x_train, y_train)
y_pred = RF.predict(x_test)
pred_prob = RF.predict_proba(x_test)

# %%
def evaluate_model(y_test, y_pred, pred_prob):
    print('confusion matrix: \n', confusion_matrix(y_test, y_pred))
    accuracy = np.round(balanced_accuracy_score(y_test, y_pred),4)
    print('accuracy: %.4f' % accuracy)
    precision = np.round(precision_score(y_test, y_pred, average='weighted'),4)
    print('precision: %.4f' % precision)
    recall = np.round(recall_score(y_test, y_pred, average='weighted'),4)
    print('recall: %.4f' % recall)
    f1score = np.round(f1_score(y_test, y_pred, average='weighted'),4)
    print('f1score: %.4f' % f1score)
    report = classification_report(y_test, y_pred, target_names=categorical_label)
    print('classification report: \n', report)

evaluate_model(y_test, y_pred, pred_prob)
# Out:
# confusion matrix:
#  [[6 0]
#  [1 8]]
# accuracy: 0.9444
# precision: 0.9429
# recall: 0.9333
# f1score: 0.9339
# classification report:
#                                 precision    recall  f1-score   support
#
# advanced (fibrosis stage 3-4)       0.86      1.00      0.92         6
#     mild (fibrosis stage 0-1)       1.00      0.89      0.94         9
#
#                      accuracy                           0.93        15
#                     macro avg       0.93      0.94      0.93        15
#                  weighted avg       0.94      0.93      0.93        15

# %% [markdown]
# ###Random Forest with Autoencoder = no difference

# %%
# Train the RandomForest model on the encoded data
# Using OneVsRest because I want to add in control group data adding another stage
RF = OneVsRestClassifier(RandomForestClassifier(max_features=.2))
RF.fit(x_train_encoded, y_train)
y_pred_encoded = RF.predict(x_test_encoded)  # Predict using the encoded test data
pred_prob_encoded = RF.predict_proba(x_test_encoded)

# %%
def evaluate_model_encoded(y_test, y_pred_encoded, pred_prob_encoded):
    print('confusion matrix: \n', confusion_matrix(y_test, y_pred))
    accuracy = np.round(balanced_accuracy_score(y_test, y_pred), 4)
    print('accuracy: %.4f' % accuracy)
    precision = np.round(precision_score(y_test, y_pred, average='weighted'), 4)
    print('precision: %.4f' % precision)
    recall = np.round(recall_score(y_test, y_pred, average='weighted'), 4)
    print('recall: %.4f' % recall)
    f1score = np.round(f1_score(y_test, y_pred, average='weighted'), 4)
    print('f1score: %.4f' % f1score)
    report = classification_report(y_test, y_pred, target_names=categorical_label)
    print('classification report: \n', report)

evaluate_model_encoded(y_test, y_pred_encoded, pred_prob_encoded)
# Out:
# confusion matrix:
#  [[6 0]
#  [1 8]]
# accuracy: 0.9444
# precision: 0.9429
# recall: 0.9333
# f1score: 0.9339
# classification report:
#                                 precision    recall  f1-score   support
#
# advanced (fibrosis stage 3-4)       0.86      1.00      0.92         6
#     mild (fibrosis stage 0-1)       1.00      0.89      0.94         9
#
#                      accuracy                           0.93        15
#                     macro avg       0.93      0.94      0.93        15
#                  weighted avg       0.94      0.93      0.93        15

# %% [markdown]
# ###Save the rf model

# %%
import joblib

# Save the model
filename = 'rf_model.sav'
joblib.dump(RF, filename)
# Out:
# ['rf_model.sav']

# %%
#use this code to use mdoel:
#loaded_model = joblib.load(filename)

# %% [markdown]
# # Hyperparameter Tuning = no difference

# %%
# from sklearn.model_selection import GridSearchCV

# # Define the parameter grid to search
# param_grid = {
#     'estimator__n_estimators': [50, 100, 200],
#     'estimator__max_depth': [None, 10, 20],
#     'estimator__min_samples_split': [2, 5, 10]
# }

# # Create a GridSearchCV object
# grid_search = GridSearchCV(RF, param_grid, cv=5, scoring='accuracy')

# # Fit the grid search to the training data
# grid_search.fit(x_train, y_train)

# # Print the best parameters found
# print("Best Parameters:", grid_search.best_params_)

# # Get the best model
# best_rf_model = grid_search.best_estimator_

# # Evaluate the best model on the test set
# y_pred_best = best_rf_model.predict(x_test)
# evaluate_model(y_test, y_pred_best, best_rf_model.predict_proba(x_test))

# %% [markdown]
# # Ensemble Methods

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.5)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.7.1)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.1.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.15.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.1.4)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)

# %% [markdown]
# ###Compare to an ensemble of models: SVM, SGBoost, Catboost

# %%
from sklearn.svm import SVC
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from sklearn.ensemble import VotingClassifier

# Initialize the individual models
svm_model = SVC(probability=True)  # Set probability=True for predict_proba
xgb_model = XGBClassifier()
catboost_model = CatBoostClassifier(verbose=0)  # Suppress CatBoost's verbose output

# Create the ensemble model
ensemble_model = VotingClassifier(
    estimators=[('svm', svm_model), ('xgb', xgb_model), ('catboost', catboost_model)],
    voting='soft'  # Use 'soft' voting for probability-based predictions
)

# Fit the ensemble model on the training data
ensemble_model.fit(x_train, y_train)

# Make predictions using the ensemble model
y_pred = ensemble_model.predict(x_test)
pred_prob = ensemble_model.predict_proba(x_test)

# Evaluate the ensemble model
evaluate_model(y_test, y_pred, pred_prob)
# Out:
# confusion matrix:
#  [[6 0]
#  [0 9]]
# accuracy: 1.0000
# precision: 1.0000
# recall: 1.0000
# f1score: 1.0000
# classification report:
#                                 precision    recall  f1-score   support
#
# advanced (fibrosis stage 3-4)       1.00      1.00      1.00         6
#     mild (fibrosis stage 0-1)       1.00      1.00      1.00         9
#
#                      accuracy                           1.00        15
#                     macro avg       1.00      1.00      1.00        15
#                  weighted avg       1.00      1.00      1.00        15

# %% [markdown]
# ### Attempting a 1D CNN Classifier. Poor results. Future potential project.

# %%
# import keras
# from keras.layers import Input, Dense, Conv1D, MaxPooling1D, Flatten, Dropout
# from keras.models import Model, Sequential
# optimizer = keras.optimizers.Adam(learning_rate=0.001)
# # Define the 1D CNN model
# def create_cnn_model(input_shape):
#     model = Sequential()
#     model.add(Conv1D(filters=32, kernel_size=3, activation='relu', input_shape=input_shape))
#     model.add(MaxPooling1D(pool_size=2))
#     model.add(Dropout(0.25))
#     model.add(Conv1D(filters=64, kernel_size=3, activation='relu'))
#     model.add(MaxPooling1D(pool_size=2))
#     model.add(Dropout(0.25))
#     model.add(Conv1D(filters=128, kernel_size=3, activation='relu'))
#     model.add(MaxPooling1D(pool_size=2))
#     model.add(Dropout(0.25))
#     model.add(Flatten())
#     model.add(Dense(64, activation='relu'))
#     model.add(Dense(len(categorical_label), activation='softmax'))  # Output layer with softmax activation

#     model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
#     return model

# # Prepare data for CNN
# x_train_cnn = x_train.reshape(x_train.shape[0], x_train.shape[1], 1)  # Reshape for 1D CNN
# x_test_cnn = x_test.reshape(x_test.shape[0], x_test.shape[1], 1)

# # Create and train the CNN model
# cnn_model = create_cnn_model(input_shape=(x_train_cnn.shape[1], 1))
# cnn_model.summary()  # Print the model architecture

# # Train the CNN model
# cnn_model.fit(x_train_cnn, y_train, epochs=30, batch_size=32, validation_data=(x_test_cnn, y_test))

# # Evaluate the CNN model
# y_pred_cnn_prob = cnn_model.predict(x_test_cnn)
# y_pred_cnn = y_pred_cnn_prob.argmax(axis=-1)  # Get the class with the highest probability

# # Evaluate the CNN model
# evaluate_model(y_test, y_pred_cnn, y_pred_cnn_prob)
